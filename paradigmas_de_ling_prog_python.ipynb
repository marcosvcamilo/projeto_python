# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosvcamilo/projeto_python/blob/main/paradigmas_de_ling_prog_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Disciplina**: Paradigmas de Lingugens de Progração Python
#
# **Professor** tutor: Sérgio Assunção Monteiro
#
# **Nome**: Marcos Vinicius Luiz Camilo
#
# **Curso**: Desenvolvimento de Software Multiplataforma
#
# ---------------------------------------------------------------------------
# **Descrição**
#  1. Importar os pacotes “pandas”, “matplotlib” e “seaborn”

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# 2. Apresente um descrito do repositório de dados:

# %%
file = 'http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data'

# %% [markdown]
# 3. Importe os dados do repositório do item 2 em um Dataframe.

# %%
df = pd.read_csv(file, skiprows=2)
df
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
# ...                        ...                  ...                 ...
# GRASS                     36.0                243.0                   9
# GRASS                    186.0                218.0                   9
# GRASS                    197.0                236.0                   9
# GRASS                    208.0                240.0                   9
# GRASS                    223.0                185.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# ...

# %% [markdown]
# 4. Apresente os 5 primeiros registros do Dataframe do item 3.

# %%
df.head(5)
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# BRICKFACE                   0.0                   0.0    0.277778  0.062963
# BRICKFACE                   0.0                   0.0    0.333333  0.266667
# BRICKFACE                   0.0                   0.0    0.277778  0.107407
# BRICKFACE                   0.0                   0.0    0.500000  0.166667
# BRICKFACE                   0.0                   0.0    0.722222  0.374074
#
# ...

# %% [markdown]
# 5. Apresente as colunas do Dataframe do item 3.

# %%
head = df.columns.to_list()
head
# Out:
# ['REGION-CENTROID-COL',
#  'REGION-CENTROID-ROW',
#  'REGION-PIXEL-COUNT',
#  'SHORT-LINE-DENSITY-5',
#  'SHORT-LINE-DENSITY-2',
#  'VEDGE-MEAN',
#  'VEDGE-SD',
#  'HEDGE-MEAN',
#  'HEDGE-SD',
#  'INTENSITY-MEAN',
#  'RAWRED-MEAN',
#  'RAWBLUE-MEAN',
#  'RAWGREEN-MEAN',
#  'EXRED-MEAN',
#  'EXBLUE-MEAN',
#  'EXGREEN-MEAN',
#  'VALUE-MEAN',
#  'SATURATION-MEAN',
#  'HUE-MEAN']

# %% [markdown]
# 6. Apresente os tipos de dados das colunas do Dataframe do item 3

# %%
df.dtypes
# Out:
# REGION-CENTROID-COL     float64
# REGION-CENTROID-ROW     float64
# REGION-PIXEL-COUNT        int64
# SHORT-LINE-DENSITY-5    float64
# SHORT-LINE-DENSITY-2    float64
# VEDGE-MEAN              float64
# VEDGE-SD                float64
# HEDGE-MEAN              float64
# HEDGE-SD                float64
# INTENSITY-MEAN          float64
# RAWRED-MEAN             float64
# RAWBLUE-MEAN            float64
# RAWGREEN-MEAN           float64
# EXRED-MEAN              float64
# EXBLUE-MEAN             float64
# EXGREEN-MEAN            float64
# VALUE-MEAN              float64
# SATURATION-MEAN         float64
# HUE-MEAN                float64
# dtype: object

# %% [markdown]
# 7. Apresente uma análise exploratória dos dados do Dataframe do item 3 (dica: utilize a função “describe”).

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
# ...                        ...                  ...                 ...
# GRASS                     36.0                243.0                   9
# GRASS                    186.0                218.0                   9
# GRASS                    197.0                236.0                   9
# GRASS                    208.0                240.0                   9
# GRASS                    223.0                185.0                   9
#
# ...

# %% [markdown]
# 8. Selecione uma das características do Dataframe e exclua os dados NA.

# %%
region_centroid_col = df['REGION-CENTROID-COL'].dropna( axis = 0)
region_centroid_col
# Out:
# BRICKFACE    140.0
# BRICKFACE    188.0
# BRICKFACE    105.0
# BRICKFACE     34.0
# BRICKFACE     39.0
#              ...
# GRASS         36.0
# GRASS        186.0
# GRASS        197.0
# GRASS        208.0
# GRASS        223.0
# Name: REGION-CENTROID-COL, Length: 210, dtype: float64

# %% [markdown]
# 9. Apresente o histograma dos dados do item 8.

# %%
sb.histplot(data = region_centroid_col, kde=True)
plt.show()

# %% [markdown]
# 10. Apresente uma conclusão do seu trabalho.
#
# Conclusão: Apesar da dificuldade do trabalho por ser uma  linguagem nova para mim, realizei muita pesquisa sobre Python,para enteder um pouco mais sobre o assunto,principalmente a library panda e seus recursos que são de grande ajuda para utililização do "colab".
# Minha maior dificuldade foi visualizar que o link estava desatualizado, me impedindo assim de da prosseguimento ao trabalho, mas com algumas horas de trabalho conseguir alterar com sucesso.Estou feliz por poder aprender um pouco mais sobre essa linguagem tão utilizada no mercado, e espero está ampliando meus conhecimento sobre Python a cada dia...
